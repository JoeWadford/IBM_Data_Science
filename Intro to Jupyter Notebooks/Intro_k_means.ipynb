# %% [markdown]
# # <font color=black>The k-means Algorithm<font>

# %% [markdown]
# ## <font> </font>

# %% [markdown]
# ## <font color=black>1. Import Data and Libraries</font>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import csv
import os
import sklearn.datasets as datasets

plt.jet() # set the color map. When your colors are lost, re-run this.

# %% [markdown]
# ## <font color=black>2. Create clusters</font>

# %%
X, Y = datasets.make_blobs(centers=4, cluster_std=0.5, random_state=0)

plt.scatter(X[:,0],X[:,1])

# %% [markdown]
# <font color=black>you can add colors using c=y</font>

# %%
plt.scatter(X[:,0], X[:,1], c=Y)

# %% [markdown]
# ## <font color=black>3. Estimating the means for each cluster</font>

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(4, random_state=8)
Y_hat = kmeans.fit(X).labels_

# %%
plt.scatter(X[:,0], X[:,1], c=Y_hat);

# %%
plt.scatter(X[:,0], X[:,1], c=Y_hat, alpha=0.4)
mu = kmeans.cluster_centers_
plt.scatter(mu[:,0], mu[:,1], s=100, c=np.unique(Y_hat))
print(mu)
# Out:
# [[-1.47935679  3.11716896]
#  [-1.26811733  7.76378266]
#  [ 1.99186903  0.96561071]
#  [ 0.92578447  4.32475792]]

# %% [markdown]
# ## <font color=black>4. k means on images</font>

# %%
from sklearn.datasets import fetch_openml
from sklearn.cluster import KMeans
from sklearn.utils import shuffle
X_digits, Y_digits = fetch_openml("mnist_784", version=1, return_X_y=True) # fetch dataset from internet

X_digits, Y_digits = shuffle(X_digits,Y_digits) # shuffle dataset (which is ordered!)
X_digits = X_digits[-5000:]       # take only the last instances, to shorten runtime of KMeans

# %%
plt.rc("image", cmap="binary") # use black/white palette for plotting
for i in range(10):
    plt.subplot(2,5,i+1)
    plt.imshow(X_digits[i].reshape(28,28))
    plt.xticks(())
    plt.yticks(())
plt.tight_layout()

# %%
kmeans = KMeans(20)
mu_digits = kmeans.fit(X_digits).cluster_centers_

# %%
plt.figure(figsize=(16,6))
for i in range(int(2*(mu_digits.shape[0]/2))): # loop over all means
    plt.subplot(2,mu_digits.shape[0]/2,i+1)
    plt.imshow(mu_digits[i].reshape(28,28))
    plt.xticks(())
    plt.yticks(())
plt.tight_layout()

# %% [markdown]
# ## <font color=black>5. Playing with kmeans</font>

# %%
from IPython.display import IFrame
IFrame('http://stackoverflow.org', width=700, height=350)
# Out:
#         <iframe
#             width="700"
#             height="350"
#             src="http://stackoverflow.org"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
